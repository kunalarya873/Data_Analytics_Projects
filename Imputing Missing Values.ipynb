# %% [markdown]
# **FIFA 19 Dataset**

# %%
#importing pandas library for reading the dataset

import pandas as pd

# %%
# Reading the dataset

data=pd.read_csv("data-1.csv")

# %%
# first five rows of the dataset

data.head()
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
# 2           2  190871          Neymar Jr   26
# 3           3  193080             De Gea   27
# 4           4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# 4   https://cdn.sofifa.org/flags/7.png       91         92
#
#                   Club  ... Composure Marking StandingTackle  SlidingTackle  \
# 0         FC Barcelona  ...      96.0    33.0           28.0           26.0
# 1             Juventus  ...      95.0    28.0           31.0           23.0
# 2  Paris Saint-Germain  ...      94.0    27.0           24.0           33.0
# 3    Manchester United  ...      68.0    15.0           21.0           13.0
# 4      Manchester City  ...      88.0    68.0           58.0           51.0
#
#   GKDiving  GKHandling  GKKicking  GKPositioning GKReflexes Release Clause
# 0      6.0        11.0       15.0           14.0        8.0        €226.5M
# 1      7.0        11.0       15.0           14.0       11.0        €127.1M
# 2      9.0         9.0       15.0           15.0       11.0        €228.1M
# 3     90.0        85.0       87.0           88.0       94.0        €138.6M
# 4     15.0        13.0        5.0           10.0       13.0        €196.4M
#
# [5 rows x 89 columns]

# %%
# printing all the columns of the dataset

data.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'Name', 'Age', 'Photo', 'Nationality', 'Flag',
#        'Overall', 'Potential', 'Club', 'Club Logo', 'Value', 'Wage', 'Special',
#        'Preferred Foot', 'International Reputation', 'Weak Foot',
#        'Skill Moves', 'Work Rate', 'Body Type', 'Real Face', 'Position',
#        'Jersey Number', 'Joined', 'Loaned From', 'Contract Valid Until',
#        'Height', 'Weight', 'LS', 'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW',
#        'LAM', 'CAM', 'RAM', 'LM', 'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM',
#        'CDM', 'RDM', 'RWB', 'LB', 'LCB', 'CB', 'RCB', 'RB', 'Crossing',
#        'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys', 'Dribbling',
#        'Curve', 'FKAccuracy', 'LongPassing', 'BallControl', 'Acceleration',
#        'SprintSpeed', 'Agility', 'Reactions', 'Balance', 'ShotPower',
#        'Jumping', 'Stamina', 'Strength', 'LongShots', 'Aggression',
#        'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure',
#        'Marking', 'StandingTackle', 'SlidingTackle', 'GKDiving', 'GKHandling',
#        'GKKicking', 'GKPositioning', 'GKReflexes', 'Release Clause'],
#       dtype='object')

# %%
# sorting the missing values in rows in descending order

data.isnull().sum(axis=1).sort_values(ascending=False)
# Out:
# 13260    75
# 13249    75
# 13276    75
# 13277    75
# 13278    75
#          ..
# 6661      1
# 6662      1
# 6663      1
# 6664      1
# 18206     1
# Length: 18207, dtype: int64

# %%
# checking if there are any missing values in rows

data.isnull().any(axis=1)
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#          ...
# 18202    True
# 18203    True
# 18204    True
# 18205    True
# 18206    True
# Length: 18207, dtype: bool

# %%
#checking if there is any row having all the values missing

data.isnull().all(axis=1).sum()

#there is no row having all the values missing
# Out:
# 0

# %%
# checking for the rows which have missing values greater than 30

data[data.isnull().sum(axis=1)>30]
# Out:
#        Unnamed: 0      ID            Name  Age  \
# 568           568  229909        A. Lunev   26
# 1120         1120  156092       J. Villar   41
# 2827         2827  189024     M. Banguera   32
# 2984         2984  205211       M. Borjan   30
# 3631         3631  224900     A. Silbeira   22
# ...           ...     ...             ...  ...
# 17129       17129  228198        J. Singh   26
# 17197       17197  245164        V. Kaith   21
# 17339       17339  233526        S. Passi   23
# 17436       17436  236452  D. Lalhlimpuia   20
# 17539       17539  234508        C. Singh   21
#
#                                                 Photo Nationality  \
# 568    https://cdn.sofifa.org/players/4/19/229909.png      Russia
# 1120   https://cdn.sofifa.org/players/4/19/156092.png    Paraguay
# 2827   https://cdn.sofifa.org/players/4/19/189024.png     Ecuador
# 2984   https://cdn.sofifa.org/players/4/19/205211.png      Canada
# 3631   https://cdn.sofifa.org/players/4/19/224900.png    Paraguay
# ...                                               ...         ...
# 17129  https://cdn.sofifa.org/players/4/19/228198.png       India
# 17197  https://cdn.sofifa.org/players/4/19/245164.png       India
# 17339  https://cdn.sofifa.org/players/4/19/233526.png       India
# 17436  https://cdn.sofifa.org/players/4/19/236452.png       India
# 17539  https://cdn.sofifa.org/players/4/19/234508.png       India
#
#                                        Flag  Overall  Potential Club  ...  \
# 568     https://cdn.sofifa.org/flags/40.png       79         81  NaN  ...
# 1120    https://cdn.sofifa.org/flags/58.png       77         77  NaN  ...
# 2827    https://cdn.sofifa.org/flags/57.png       73         73  NaN  ...
# 2984    https://cdn.sofifa.org/flags/70.png       73         73  NaN  ...
# 3631    https://cdn.sofifa.org/flags/58.png       72         72  NaN  ...
# ...                                     ...      ...        ...  ...  ...
# 17129  https://cdn.sofifa.org/flags/159.png       55         58  NaN  ...
# 17197  https://cdn.sofifa.org/flags/159.png       55         64  NaN  ...
# 17339  https://cdn.sofifa.org/flags/159.png       54         63  NaN  ...
# 17436  https://cdn.sofifa.org/flags/159.png       54         67  NaN  ...
# 17539  https://cdn.sofifa.org/flags/159.png       53         62  NaN  ...
#
#       Composure Marking StandingTackle  SlidingTackle GKDiving  GKHandling  \
# 568        69.0    18.0           20.0           12.0     80.0        73.0
# 1120       55.0    13.0           13.0           14.0     75.0        75.0
# 2827       39.0    15.0           16.0           14.0     68.0        70.0
# 2984       58.0    19.0           23.0           21.0     75.0        71.0
# 3631       27.0    16.0           14.0           15.0     71.0        70.0
# ...         ...     ...            ...            ...      ...         ...
# 17129      42.0    26.0           18.0           13.0     15.0        14.0
# 17197      29.0     8.0           12.0           11.0     55.0        50.0
# 17339      45.0    14.0           23.0           21.0      8.0         6.0
# 17436      46.0    26.0           17.0           13.0      7.0         8.0
# 17539      41.0    56.0           49.0           53.0     12.0         9.0
#
#        GKKicking  GKPositioning GKReflexes Release Clause
# 568         65.0           77.0       85.0            NaN
# 1120        74.0           78.0       77.0            NaN
# 2827        65.0           77.0       77.0            NaN
# 2984        71.0           73.0       72.0            NaN
# 3631        62.0           70.0       72.0            NaN
# ...          ...            ...        ...            ...
# 17129        8.0           10.0       16.0            NaN
# 17197       57.0           59.0       53.0            NaN
# 17339       13.0            9.0       10.0            NaN
# 17436       12.0           11.0       11.0            NaN
# 17539        6.0           14.0        8.0            NaN
#
# [93 rows x 89 columns]

# %% [markdown]
# We can observe that there are 93 rows which has more than 30 missing values

# %%
print("before deleting the rows",data.shape[0])
# Out:
# before deleting the rows 18207

# %%
data=data[data.isnull().sum(axis=1)<=30]

print("after deleting the rows",data.shape[0])
# Out:
# after deleting the rows 18114

# %%
# checking for the missing values in columns 

data.isnull().sum()
# Out:
# Unnamed: 0           0
# ID                   0
# Name                 0
# Age                  0
# Photo                0
#                   ...
# GKHandling           0
# GKKicking            0
# GKPositioning        0
# GKReflexes           0
# Release Clause    1471
# Length: 89, dtype: int64

# %% [markdown]
# **Only first 5 and last 5 are being shown above. So, we will use max_rows to see all the rows**

# %%
pd.set_option("max_rows",89)
data.isnull().sum()
# Out:
# Unnamed: 0                      0
# ID                              0
# Name                            0
# Age                             0
# Photo                           0
# Nationality                     0
# Flag                            0
# Overall                         0
# Potential                       0
# Club                          196
# Club Logo                       0
# Value                           0
# Wage                            0
# Special                         0
# Preferred Foot                  0
# International Reputation        0
# Weak Foot                       0
# Skill Moves                     0
# Work Rate                       0
# Body Type                       0
# Real Face                       0
# Position                        0
# Jersey Number                   0
# Joined                       1460
# Loaned From                 16850
# Contract Valid Until          196
# Height                          0
# Weight                          0
# LS                           1992
# ST                           1992
# RS                           1992
# LW                           1992
# LF                           1992
# CF                           1992
# RF                           1992
# RW                           1992
# LAM                          1992
# CAM                          1992
# RAM                          1992
# LM                           1992
# LCM                          1992
# CM                           1992
# RCM                          1992
# RM                           1992
# LWB                          1992
# LDM                          1992
# CDM                          1992
# RDM                          1992
# RWB                          1992
# LB                           1992
# LCB                          1992
# CB                           1992
# RCB                          1992
# RB                           1992
# Crossing                        0
# Finishing                       0
# HeadingAccuracy                 0
# ShortPassing                    0
# Volleys                         0
# Dribbling                       0
# Curve                           0
# FKAccuracy                      0
# LongPassing                     0
# BallControl                     0
# Acceleration                    0
# SprintSpeed                     0
# Agility                         0
# Reactions                       0
# Balance                         0
# ShotPower                       0
# Jumping                         0
# Stamina                         0
# Strength                        0
# LongShots                       0
# Aggression                      0
# Interceptions                   0
# Positioning                     0
# Vision                          0
# Penalties                       0
# Composure                       0
# Marking                         0
# StandingTackle                  0
# SlidingTackle                   0
# GKDiving                        0
# GKHandling                      0
# GKKicking                       0
# GKPositioning                   0
# GKReflexes                      0
# Release Clause               1471
# dtype: int64

# %%
# checking percentage of missing values in each column of the dataset  
# we create a dataframe and sort the values by the percentage of missing values in descending order
x=data.isnull().sum()
y=(data.isnull().sum()/data.shape[0])*100
z={'Number of missing values':x,'Percentage of missing values':y}
df=pd.DataFrame(z,columns=['Number of missing values','Percentage of missing values'])
df.sort_values(by='Percentage of missing values',ascending=False)
# Out:
#                           Number of missing values  \
# Loaned From                                  16850
# LWB                                           1992
# LCM                                           1992
# RS                                            1992
# LW                                            1992
# LF                                            1992
# CF                                            1992
# RF                                            1992
# RW                                            1992
# LAM                                           1992
# CAM                                           1992
# RAM                                           1992
# LM                                            1992
# CM                                            1992
# LS                                            1992
# RCM                                           1992
# RM                                            1992
# LDM                                           1992
# CDM                                           1992
# RDM                                           1992
# RWB                                           1992
# LB                                            1992
# LCB                                           1992
# CB                                            1992
# RCB                                           1992
# RB                                            1992
# ST                                            1992
# Release Clause                                1471
# Joined                                        1460
# Club                                           196
# Contract Valid Until                           196
# Balance                                          0
# LongShots                                        0
# Strength                                         0
# Stamina                                          0
# Jumping                                          0
# ShotPower                                        0
# Weight                                           0
# Reactions                                        0
# Aggression                                       0
# SprintSpeed                                      0
# Acceleration                                     0
# BallControl                                      0
# LongPassing                                      0
# Agility                                          0
# Interceptions                                    0
# Curve                                            0
# Positioning                                      0
# Vision                                           0
# Penalties                                        0
# Composure                                        0
# Marking                                          0
# StandingTackle                                   0
# SlidingTackle                                    0
# GKDiving                                         0
# GKHandling                                       0
# GKKicking                                        0
# GKPositioning                                    0
# GKReflexes                                       0
# FKAccuracy                                       0
# Volleys                                          0
# Dribbling                                        0
# Height                                           0
# Jersey Number                                    0
# Position                                         0
# Real Face                                        0
# Body Type                                        0
# Work Rate                                        0
# Skill Moves                                      0
# Weak Foot                                        0
# International Reputation                         0
# Preferred Foot                                   0
# Special                                          0
# Wage                                             0
# Value                                            0
# ID                                               0
# Club Logo                                        0
# Potential                                        0
# Overall                                          0
# Flag                                             0
# Nationality                                      0
# Photo                                            0
# Age                                              0
# Name                                             0
# Crossing                                         0
# Finishing                                        0
# HeadingAccuracy                                  0
# ShortPassing                                     0
# Unnamed: 0                                       0
#
#                           Percentage of missing values
# Loaned From                                  93.021972
# LWB                                          10.997019
# LCM                                          10.997019
# RS                                           10.997019
# LW                                           10.997019
# LF                                           10.997019
# CF                                           10.997019
# RF                                           10.997019
# RW                                           10.997019
# LAM                                          10.997019
# CAM                                          10.997019
# RAM                                          10.997019
# LM                                           10.997019
# CM                                           10.997019
# LS                                           10.997019
# RCM                                          10.997019
# RM                                           10.997019
# LDM                                          10.997019
# CDM                                          10.997019
# RDM                                          10.997019
# RWB                                          10.997019
# LB                                           10.997019
# LCB                                          10.997019
# CB                                           10.997019
# RCB                                          10.997019
# RB                                           10.997019
# ST                                           10.997019
# Release Clause                                8.120791
# Joined                                        8.060064
# Club                                          1.082036
# Contract Valid Until                          1.082036
# Balance                                       0.000000
# LongShots                                     0.000000
# Strength                                      0.000000
# Stamina                                       0.000000
# Jumping                                       0.000000
# ShotPower                                     0.000000
# Weight                                        0.000000
# Reactions                                     0.000000
# Aggression                                    0.000000
# SprintSpeed                                   0.000000
# Acceleration                                  0.000000
# BallControl                                   0.000000
# LongPassing                                   0.000000
# Agility                                       0.000000
# Interceptions                                 0.000000
# Curve                                         0.000000
# Positioning                                   0.000000
# Vision                                        0.000000
# Penalties                                     0.000000
# Composure                                     0.000000
# Marking                                       0.000000
# StandingTackle                                0.000000
# SlidingTackle                                 0.000000
# GKDiving                                      0.000000
# GKHandling                                    0.000000
# GKKicking                                     0.000000
# GKPositioning                                 0.000000
# GKReflexes                                    0.000000
# FKAccuracy                                    0.000000
# Volleys                                       0.000000
# Dribbling                                     0.000000
# Height                                        0.000000
# Jersey Number                                 0.000000
# Position                                      0.000000
# Real Face                                     0.000000
# Body Type                                     0.000000
# Work Rate                                     0.000000
# Skill Moves                                   0.000000
# Weak Foot                                     0.000000
# International Reputation                      0.000000
# Preferred Foot                                0.000000
# Special                                       0.000000
# Wage                                          0.000000
# Value                                         0.000000
# ID                                            0.000000
# Club Logo                                     0.000000
# Potential                                     0.000000
# Overall                                       0.000000
# Flag                                          0.000000
# Nationality                                   0.000000
# Photo                                         0.000000
# Age                                           0.000000
# Name                                          0.000000
# Crossing                                      0.000000
# Finishing                                     0.000000
# HeadingAccuracy                               0.000000
# ShortPassing                                  0.000000
# Unnamed: 0                                    0.000000

# %%
# We can observe that column Loaned From has 93% of Missing values, which is very high, so it is better to drop it rather imputing values
data=data.drop(['Loaned From'],axis=1)

# %%
# Let's check the columns after removing Loaned From coulmn
print(data.columns)
# Out:
# Index(['Unnamed: 0', 'ID', 'Name', 'Age', 'Photo', 'Nationality', 'Flag',
#        'Overall', 'Potential', 'Club', 'Club Logo', 'Value', 'Wage', 'Special',
#        'Preferred Foot', 'International Reputation', 'Weak Foot',
#        'Skill Moves', 'Work Rate', 'Body Type', 'Real Face', 'Position',
#        'Jersey Number', 'Joined', 'Contract Valid Until', 'Height', 'Weight',
#        'LS', 'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW', 'LAM', 'CAM', 'RAM',
#        'LM', 'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM', 'CDM', 'RDM', 'RWB', 'LB',
#        'LCB', 'CB', 'RCB', 'RB', 'Crossing', 'Finishing', 'HeadingAccuracy',
#        'ShortPassing', 'Volleys', 'Dribbling', 'Curve', 'FKAccuracy',
#        'LongPassing', 'BallControl', 'Acceleration', 'SprintSpeed', 'Agility',
#        'Reactions', 'Balance', 'ShotPower', 'Jumping', 'Stamina', 'Strength',
#        'LongShots', 'Aggression', 'Interceptions', 'Positioning', 'Vision',
#        'Penalties', 'Composure', 'Marking', 'StandingTackle', 'SlidingTackle',
#        'GKDiving', 'GKHandling', 'GKKicking', 'GKPositioning', 'GKReflexes',
#        'Release Clause'],
#       dtype='object')

# %%
# Lets check the data type of the remaining columns which are having missing values

data.dtypes[data.isnull().any()]
# Out:
# Club                    object
# Joined                  object
# Contract Valid Until    object
# LS                      object
# ST                      object
# RS                      object
# LW                      object
# LF                      object
# CF                      object
# RF                      object
# RW                      object
# LAM                     object
# CAM                     object
# RAM                     object
# LM                      object
# LCM                     object
# CM                      object
# RCM                     object
# RM                      object
# LWB                     object
# LDM                     object
# CDM                     object
# RDM                     object
# RWB                     object
# LB                      object
# LCB                     object
# CB                      object
# RCB                     object
# RB                      object
# Release Clause          object
# dtype: object

# %%
# imputing missing values for categorical columns

data['Club']=data['Club'].fillna(data['Club'].mode()[0])
data['Position']=data['Position'].fillna(data['Position'].mode()[0])
data['Joined']=data['Joined'].fillna(data['Joined'].mode()[0])
data['Contract Valid Until']=data['Contract Valid Until'].fillna(data['Contract Valid Until'].mode()[0])
data['Release Clause']=data['Release Clause'].fillna(data['Release Clause'].mode()[0])

# %%
# Business Logic - These columns represent the player position and score for that position
# So, if the data  is not available for a player then it means - That Player does not play for that position. 
# So, we can impute 0 as his score for that position
data['RB'].fillna(0,inplace=True)
data['RCB'].fillna(0,inplace=True)
data['CB'].fillna(0,inplace=True)
data['LCB'].fillna(0,inplace=True)
data['LB'].fillna(0,inplace=True)
data['RWB'].fillna(0,inplace=True)
data['RDM'].fillna(0,inplace=True)
data['CDM'].fillna(0,inplace=True)
data['LDM'].fillna(0,inplace=True)
data['LWB'].fillna(0,inplace=True)
data['RM'].fillna(0,inplace=True)
data['RCM'].fillna(0,inplace=True)
data['CM'].fillna(0,inplace=True)
data['LCM'].fillna(0,inplace=True)
data['LM'].fillna(0,inplace=True)
data['RAM'].fillna(0,inplace=True)
data['CAM'].fillna(0,inplace=True)
data['LAM'].fillna(0,inplace=True)
data['RW'].fillna(0,inplace=True)
data['RF'].fillna(0,inplace=True)
data['CF'].fillna(0,inplace=True)
data['LF'].fillna(0,inplace=True)
data['LW'].fillna(0,inplace=True)
data['RS'].fillna(0,inplace=True)
data['ST'].fillna(0,inplace=True)
data['LS'].fillna(0,inplace=True)

# %%
# to impute all at once we can use 
 # data.fillna(0,inplace=True)
# Check if there are still missing values

data.isnull().sum().sum()
# Out:
# 0
